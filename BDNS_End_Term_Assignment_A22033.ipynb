# %% [markdown]
# #Extracting data from Github

# %%
# !wget -q https://github.com/Soujatya10/BDNS_PROJECT-USING-SPARK-AND-ML/blob/main/CAR_DETAILS_FROM_CAR_DEKHO.csv

# %%
import pandas as pd
import numpy as np
import pymongo
import json

# %%
xy=pd.read_csv("CAR_DETAILS_FROM_CAR_DEKHO.csv")

# %% [markdown]
# #Reading the Data

# %%
data=xy.to_dict(orient="records")
data
# Out:
# [{'name': 'Maruti 800 AC',
#   'year': 2007,
#   'selling_price': 60000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R LXI Minor',
#   'year': 2007,
#   'selling_price': 135000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Verna 1.6 SX',
#   'year': 2012,
#   'selling_price': 600000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Datsun RediGO T Option',
#   'year': 2017,
#   'selling_price': 250000,
#   'km_driven': 46000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Amaze VX i-DTEC',
#   'year': 2014,
#   'selling_price': 450000,
#   'km_driven': 141000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Alto LX BSIII',
#   'year': 2007,
#   'selling_price': 140000,
#   'km_driven': 125000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Xcent 1.2 Kappa S',
#   'year': 2016,
#   'selling_price': 550000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indigo Grand Petrol',
#   'year': 2014,
#   'selling_price': 240000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Creta 1.6 VTVT S',
#   'year': 2015,
#   'selling_price': 850000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Celerio Green VXI',
#   'year': 2017,
#   'selling_price': 365000,
#   'km_driven': 78000,
#   'fuel': 'CNG',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Sail 1.2 Base',
#   'year': 2015,
#   'selling_price': 260000,
#   'km_driven': 35000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indigo Grand Petrol',
#   'year': 2014,
#   'selling_price': 250000,
#   'km_driven': 100000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Corolla Altis 1.8 VL CVT',
#   'year': 2018,
#   'selling_price': 1650000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti 800 AC',
#   'year': 2007,
#   'selling_price': 60000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R LXI Minor',
#   'year': 2007,
#   'selling_price': 135000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Verna 1.6 SX',
#   'year': 2012,
#   'selling_price': 600000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Datsun RediGO T Option',
#   'year': 2017,
#   'selling_price': 250000,
#   'km_driven': 46000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Amaze VX i-DTEC',
#   'year': 2014,
#   'selling_price': 450000,
#   'km_driven': 141000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Alto LX BSIII',
#   'year': 2007,
#   'selling_price': 140000,
#   'km_driven': 125000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Xcent 1.2 Kappa S',
#   'year': 2016,
#   'selling_price': 550000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indigo Grand Petrol',
#   'year': 2014,
#   'selling_price': 240000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Creta 1.6 VTVT S',
#   'year': 2015,
#   'selling_price': 850000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Celerio Green VXI',
#   'year': 2017,
#   'selling_price': 365000,
#   'km_driven': 78000,
#   'fuel': 'CNG',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Sail 1.2 Base',
#   'year': 2015,
#   'selling_price': 260000,
#   'km_driven': 35000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indigo Grand Petrol',
#   'year': 2014,
#   'selling_price': 250000,
#   'km_driven': 100000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Corolla Altis 1.8 VL CVT',
#   'year': 2018,
#   'selling_price': 1650000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ciaz VXi Plus',
#   'year': 2015,
#   'selling_price': 585000,
#   'km_driven': 24000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Venue SX Opt Diesel',
#   'year': 2019,
#   'selling_price': 1195000,
#   'km_driven': 5000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Enjoy TCDi LTZ 7 Seater',
#   'year': 2013,
#   'selling_price': 390000,
#   'km_driven': 33000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Jaguar XF 2.2 Litre Luxury',
#   'year': 2014,
#   'selling_price': 1964999,
#   'km_driven': 28000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mercedes-Benz New C-Class 220 CDI AT',
#   'year': 2013,
#   'selling_price': 1425000,
#   'km_driven': 59000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Vitara Brezza ZDi Plus AMT',
#   'year': 2018,
#   'selling_price': 975000,
#   'km_driven': 4500,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Audi Q5 2.0 TDI',
#   'year': 2011,
#   'selling_price': 1190000,
#   'km_driven': 175900,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Honda City V MT',
#   'year': 2018,
#   'selling_price': 930000,
#   'km_driven': 14500,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Tigor 1.2 Revotron XT',
#   'year': 2018,
#   'selling_price': 525000,
#   'km_driven': 15000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Audi A6 2.0 TDI  Design Edition',
#   'year': 2013,
#   'selling_price': 1735000,
#   'km_driven': 50000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mercedes-Benz New C-Class C 220 CDI Avantgarde',
#   'year': 2012,
#   'selling_price': 1375000,
#   'km_driven': 33800,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Skoda Superb Ambition 2.0 TDI CR AT',
#   'year': 2011,
#   'selling_price': 450000,
#   'km_driven': 130400,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Toyota Corolla Altis G AT',
#   'year': 2016,
#   'selling_price': 900000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Innova 2.5 G (Diesel) 7 Seater',
#   'year': 2015,
#   'selling_price': 1300000,
#   'km_driven': 80000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Jeep Compass 1.4 Sport Plus BSIV',
#   'year': 2019,
#   'selling_price': 1400000,
#   'km_driven': 10000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mercedes-Benz E-Class E 200 CGI Elegance',
#   'year': 2010,
#   'selling_price': 850000,
#   'km_driven': 119000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i10 Magna 1.1L',
#   'year': 2014,
#   'selling_price': 229999,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'BMW 3 Series 320d Sport Line',
#   'year': 2013,
#   'selling_price': 1550000,
#   'km_driven': 75800,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Audi Q7 35 TDI Quattro Premium',
#   'year': 2009,
#   'selling_price': 1250000,
#   'km_driven': 78000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'Third Owner'},
#  {'name': 'Hyundai Elantra CRDi S',
#   'year': 2012,
#   'selling_price': 625000,
#   'km_driven': 40000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio 1.99 S10',
#   'year': 2014,
#   'selling_price': 1050000,
#   'km_driven': 50000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda City i DTEC V',
#   'year': 2014,
#   'selling_price': 560000,
#   'km_driven': 74000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Wagon R VXI BS IV with ABS',
#   'year': 2014,
#   'selling_price': 290000,
#   'km_driven': 64000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Wagon R VXI BS IV',
#   'year': 2012,
#   'selling_price': 275000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Mahindra Scorpio LX',
#   'year': 2009,
#   'selling_price': 411000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Santro Xing GLS',
#   'year': 2009,
#   'selling_price': 150000,
#   'km_driven': 79000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Hyundai Grand i10 1.2 Kappa Asta',
#   'year': 2019,
#   'selling_price': 500000,
#   'km_driven': 15000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto LXi',
#   'year': 2006,
#   'selling_price': 100000,
#   'km_driven': 80000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift Dzire VDI Optional',
#   'year': 2017,
#   'selling_price': 725000,
#   'km_driven': 18500,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Eeco 5 Seater AC BSIV',
#   'year': 2018,
#   'selling_price': 401000,
#   'km_driven': 10200,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 Sportz 1.4 CRDi',
#   'year': 2018,
#   'selling_price': 750000,
#   'km_driven': 29000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Omni Maruti Omni MPI STD BSIII 5-STR W/ IMMOBILISER',
#   'year': 2018,
#   'selling_price': 310000,
#   'km_driven': 28000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift ZDi BSIV',
#   'year': 2016,
#   'selling_price': 665000,
#   'km_driven': 46000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 2015-2017 Sportz Option 1.4 CRDi',
#   'year': 2014,
#   'selling_price': 465000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto LXi',
#   'year': 2012,
#   'selling_price': 160000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Mahindra Jeep CL 500 MDI',
#   'year': 1996,
#   'selling_price': 250000,
#   'km_driven': 35000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Honda City i DTEC VX',
#   'year': 2014,
#   'selling_price': 675000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R VXI BS IV',
#   'year': 2013,
#   'selling_price': 300000,
#   'km_driven': 80000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indica DLS',
#   'year': 2005,
#   'selling_price': 70000,
#   'km_driven': 80000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Magna Plus',
#   'year': 2014,
#   'selling_price': 240000,
#   'km_driven': 73300,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Toyota Etios GD',
#   'year': 2014,
#   'selling_price': 525000,
#   'km_driven': 92000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto LXi',
#   'year': 2009,
#   'selling_price': 151000,
#   'km_driven': 66764,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Alto LXi',
#   'year': 2009,
#   'selling_price': 140000,
#   'km_driven': 100000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII',
#   'year': 2010,
#   'selling_price': 280000,
#   'km_driven': 350000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Toyota Corolla Altis Diesel D4DG',
#   'year': 2011,
#   'selling_price': 350000,
#   'km_driven': 230000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio 1.99 S6 Plus',
#   'year': 2017,
#   'selling_price': 570000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Magna Plus',
#   'year': 2018,
#   'selling_price': 300000,
#   'km_driven': 31000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indigo Classic Dicor',
#   'year': 2007,
#   'selling_price': 100000,
#   'km_driven': 39000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Innova 2.5 V Diesel 8-seater',
#   'year': 2009,
#   'selling_price': 500000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Tata Indica Vista Quadrajet LS',
#   'year': 2014,
#   'selling_price': 125000,
#   'km_driven': 166000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Maruti Swift 1.3 VXi',
#   'year': 2006,
#   'selling_price': 130000,
#   'km_driven': 110000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Ford EcoSport 1.5 Diesel Titanium BSIV',
#   'year': 2017,
#   'selling_price': 925000,
#   'km_driven': 35000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ciaz 1.3 Delta',
#   'year': 2018,
#   'selling_price': 750000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Civic 1.8 V AT',
#   'year': 2007,
#   'selling_price': 200000,
#   'km_driven': 54000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai i10 Sportz 1.2',
#   'year': 2010,
#   'selling_price': 248000,
#   'km_driven': 63000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Skoda Rapid 1.5 TDI Elegance',
#   'year': 2014,
#   'selling_price': 450000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Getz GLS',
#   'year': 2005,
#   'selling_price': 80000,
#   'km_driven': 120000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Nissan Terrano XL',
#   'year': 2014,
#   'selling_price': 650000,
#   'km_driven': 76000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Grand i10 CRDi Sportz',
#   'year': 2015,
#   'selling_price': 450000,
#   'km_driven': 80000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Elite i20 Diesel Era',
#   'year': 2019,
#   'selling_price': 650000,
#   'km_driven': 25000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Amaze S i-VTEC',
#   'year': 2016,
#   'selling_price': 495000,
#   'km_driven': 11958,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Brio S MT',
#   'year': 2015,
#   'selling_price': 371000,
#   'km_driven': 20000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Creta 1.6 SX Option',
#   'year': 2017,
#   'selling_price': 1025000,
#   'km_driven': 9000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mercedes-Benz S-Class S 350d Connoisseurs Edition',
#   'year': 2017,
#   'selling_price': 8150000,
#   'km_driven': 6500,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra XUV500 W8 2WD',
#   'year': 2015,
#   'selling_price': 750000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Renault Duster 85PS Diesel RxL Optional',
#   'year': 2013,
#   'selling_price': 600000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro Xing XO',
#   'year': 2007,
#   'selling_price': 80000,
#   'km_driven': 58000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Mahindra Bolero 2011-2019 SLE',
#   'year': 2013,
#   'selling_price': 325000,
#   'km_driven': 62200,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Audi A6 2.0 TDI Premium Plus',
#   'year': 2014,
#   'selling_price': 1470000,
#   'km_driven': 34000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Fiat Avventura MULTIJET Emotion',
#   'year': 2015,
#   'selling_price': 350000,
#   'km_driven': 53000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Audi A8 4.2 TDI',
#   'year': 2013,
#   'selling_price': 2800000,
#   'km_driven': 49000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Datsun RediGO 1.0 S',
#   'year': 2017,
#   'selling_price': 210000,
#   'km_driven': 15000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Volkswagen Jetta 1.4 TSI Comfortline',
#   'year': 2013,
#   'selling_price': 450000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Audi A4 2.0 TDI 177 Bhp Premium Plus',
#   'year': 2013,
#   'selling_price': 1150000,
#   'km_driven': 53000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Honda Civic 1.8 V AT',
#   'year': 2009,
#   'selling_price': 210000,
#   'km_driven': 63500,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mercedes-Benz E-Class Exclusive E 200 BSIV',
#   'year': 2018,
#   'selling_price': 4500000,
#   'km_driven': 9800,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'BMW X1 sDrive 20d xLine',
#   'year': 2017,
#   'selling_price': 2750000,
#   'km_driven': 13000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Volvo V40 D3 R Design',
#   'year': 2018,
#   'selling_price': 1975000,
#   'km_driven': 21000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti SX4 Zxi BSIII',
#   'year': 2008,
#   'selling_price': 175000,
#   'km_driven': 29173,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'BMW 7 Series 730Ld',
#   'year': 2012,
#   'selling_price': 2500000,
#   'km_driven': 48000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Bolero Power Plus SLX',
#   'year': 2017,
#   'selling_price': 628000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Sonata CRDi M/T',
#   'year': 2010,
#   'selling_price': 600000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Nissan Micra Active XV Petrol',
#   'year': 2017,
#   'selling_price': 399000,
#   'km_driven': 30000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Xylo D4',
#   'year': 2018,
#   'selling_price': 750000,
#   'km_driven': 87000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Elite i20 Sportz Plus Dual Tone BSIV',
#   'year': 2019,
#   'selling_price': 750000,
#   'km_driven': 15000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Renault KWID RXT',
#   'year': 2017,
#   'selling_price': 315000,
#   'km_driven': 16000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Xylo E4 BS III',
#   'year': 2012,
#   'selling_price': 600000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R LXI Minor',
#   'year': 2010,
#   'selling_price': 100000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Maruti SX4 ZXI MT BSIV',
#   'year': 2011,
#   'selling_price': 250000,
#   'km_driven': 110000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Renault KWID RXT',
#   'year': 2017,
#   'selling_price': 350000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Creta 1.4 CRDi S',
#   'year': 2016,
#   'selling_price': 780000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift Dzire VDI',
#   'year': 2014,
#   'selling_price': 434000,
#   'km_driven': 79350,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Verna 1.6 VTVT AT S Option',
#   'year': 2016,
#   'selling_price': 690000,
#   'km_driven': 80000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio LX BSIV',
#   'year': 2014,
#   'selling_price': 555000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti SX4 Vxi BSIII',
#   'year': 2007,
#   'selling_price': 120000,
#   'km_driven': 90000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Ertiga VDI',
#   'year': 2014,
#   'selling_price': 500000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Chevrolet Beat Diesel',
#   'year': 2013,
#   'selling_price': 165000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Zen LX',
#   'year': 2004,
#   'selling_price': 95000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Baleno Delta 1.2',
#   'year': 2018,
#   'selling_price': 550000,
#   'km_driven': 20000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift Vdi BSIII',
#   'year': 2007,
#   'selling_price': 100000,
#   'km_driven': 110000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Tata Nano Lx BSIV',
#   'year': 2012,
#   'selling_price': 100000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Toyota Innova 2.5 GX (Diesel) 8 Seater',
#   'year': 2012,
#   'selling_price': 500000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ertiga SHVS VDI',
#   'year': 2016,
#   'selling_price': 800000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Creta 1.6 CRDi SX',
#   'year': 2016,
#   'selling_price': 840000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Honda Amaze S i-Vtech',
#   'year': 2016,
#   'selling_price': 490000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indica Vista Aqua 1.4 TDI',
#   'year': 2010,
#   'selling_price': 125000,
#   'km_driven': 81000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Chevrolet Tavera Neo 2 LS B4 7 Str BSIII',
#   'year': 2012,
#   'selling_price': 400000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Chevrolet Cruze LTZ',
#   'year': 2015,
#   'selling_price': 1000000,
#   'km_driven': 3600,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Ford Figo Aspire 1.2 Ti-VCT Titanium Plus',
#   'year': 2015,
#   'selling_price': 530000,
#   'km_driven': 14272,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Ford EcoSport 1.5 Diesel Titanium Plus BSIV',
#   'year': 2017,
#   'selling_price': 840000,
#   'km_driven': 49213,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i10 Sportz 1.1L',
#   'year': 2015,
#   'selling_price': 229999,
#   'km_driven': 40000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti 800 Std',
#   'year': 1998,
#   'selling_price': 40000,
#   'km_driven': 40000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Chevrolet Spark 1.0 LS',
#   'year': 2012,
#   'selling_price': 130000,
#   'km_driven': 80000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Era Plus',
#   'year': 2015,
#   'selling_price': 200000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indica Vista Aqua TDI BSIII',
#   'year': 2011,
#   'selling_price': 120000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro LP zipPlus',
#   'year': 2003,
#   'selling_price': 75000,
#   'km_driven': 57000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Bolt Quadrajet XE',
#   'year': 2016,
#   'selling_price': 250000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti 800 AC BSIII',
#   'year': 2005,
#   'selling_price': 100000,
#   'km_driven': 30000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Era Plus',
#   'year': 2013,
#   'selling_price': 280000,
#   'km_driven': 3240,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai i20 Magna 1.2',
#   'year': 2015,
#   'selling_price': 540000,
#   'km_driven': 5000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 1.2 Asta',
#   'year': 2018,
#   'selling_price': 700000,
#   'km_driven': 10000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ciaz VDi Plus',
#   'year': 2015,
#   'selling_price': 525000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 Asta 1.4 CRDi',
#   'year': 2016,
#   'selling_price': 430000,
#   'km_driven': 80000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro LE',
#   'year': 2002,
#   'selling_price': 65000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Vitara Brezza VDi',
#   'year': 2018,
#   'selling_price': 800000,
#   'km_driven': 35000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro Xing XL eRLX Euro III',
#   'year': 2007,
#   'selling_price': 75000,
#   'km_driven': 114000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Getz 1.3 GLS',
#   'year': 2008,
#   'selling_price': 210000,
#   'km_driven': 53772,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Quanto C8',
#   'year': 2012,
#   'selling_price': 195000,
#   'km_driven': 140000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Chevrolet Tavera Neo 3 LS 7 C BSIII',
#   'year': 2015,
#   'selling_price': 400000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Magna Plus',
#   'year': 2012,
#   'selling_price': 170000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Renault KWID RXT',
#   'year': 2016,
#   'selling_price': 225000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R DUO LPG',
#   'year': 2014,
#   'selling_price': 210000,
#   'km_driven': 90000,
#   'fuel': 'LPG',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R LXI',
#   'year': 2020,
#   'selling_price': 240000,
#   'km_driven': 120000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Enjoy 1.3 TCDi LS 8',
#   'year': 2015,
#   'selling_price': 300000,
#   'km_driven': 175000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Spark 1.0 LS',
#   'year': 2011,
#   'selling_price': 99000,
#   'km_driven': 100000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Honda City i VTEC SV',
#   'year': 2014,
#   'selling_price': 620000,
#   'km_driven': 36000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Amaze VX i-DTEC',
#   'year': 2013,
#   'selling_price': 500000,
#   'km_driven': 30000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Jaguar XJ 5.0 L V8 Supercharged',
#   'year': 2010,
#   'selling_price': 2550000,
#   'km_driven': 40000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Honda Brio E MT',
#   'year': 2013,
#   'selling_price': 260000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Swift VVT ZXI',
#   'year': 2017,
#   'selling_price': 550000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indigo CR4',
#   'year': 2011,
#   'selling_price': 150000,
#   'km_driven': 155500,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i10 Asta AT',
#   'year': 2011,
#   'selling_price': 350000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Chevrolet Beat LT',
#   'year': 2016,
#   'selling_price': 320000,
#   'km_driven': 40000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift VDI BSIV',
#   'year': 2015,
#   'selling_price': 400000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Maruti Alto LXi',
#   'year': 2012,
#   'selling_price': 175000,
#   'km_driven': 80000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Chevrolet Beat LT',
#   'year': 2011,
#   'selling_price': 120000,
#   'km_driven': 90000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Renault Duster 110PS Diesel RxZ',
#   'year': 2013,
#   'selling_price': 320000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Santro Xing XG',
#   'year': 2006,
#   'selling_price': 70000,
#   'km_driven': 110000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Maruti Swift Dzire ZXI Plus',
#   'year': 2019,
#   'selling_price': 810000,
#   'km_driven': 15000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti 800 AC',
#   'year': 2007,
#   'selling_price': 95000,
#   'km_driven': 100000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Alto K10 LXI CNG',
#   'year': 2020,
#   'selling_price': 282000,
#   'km_driven': 40000,
#   'fuel': 'CNG',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti 800 Std BSII',
#   'year': 2004,
#   'selling_price': 80000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Tata Nano LX SE',
#   'year': 2013,
#   'selling_price': 72000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 Magna 1.2',
#   'year': 2016,
#   'selling_price': 600000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Skoda Rapid 1.6 MPI Ambition With Alloy Wheel',
#   'year': 2015,
#   'selling_price': 640000,
#   'km_driven': 23000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto K10 VXI',
#   'year': 2018,
#   'selling_price': 380000,
#   'km_driven': 22155,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ciaz 1.4 Delta',
#   'year': 2018,
#   'selling_price': 650000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto LX',
#   'year': 2009,
#   'selling_price': 150000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai i20 Asta',
#   'year': 2009,
#   'selling_price': 280000,
#   'km_driven': 110000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Tata Nexon 1.2 Revotron XM',
#   'year': 2018,
#   'selling_price': 430000,
#   'km_driven': 30000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Bolero Power Plus SLX',
#   'year': 2019,
#   'selling_price': 800000,
#   'km_driven': 15000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Zen D',
#   'year': 2003,
#   'selling_price': 75000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Volkswagen Vento Celeste 1.5 TDI Highline AT',
#   'year': 2016,
#   'selling_price': 650000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Eeco 7 Seater Standard BSIV',
#   'year': 2017,
#   'selling_price': 390000,
#   'km_driven': 24000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda City 1.5 EXI',
#   'year': 2005,
#   'selling_price': 100000,
#   'km_driven': 120000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Mercedes-Benz New C-Class 220 CDI AT',
#   'year': 2013,
#   'selling_price': 1500000,
#   'km_driven': 35000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti SX4 Zxi with Leather BSIII',
#   'year': 2007,
#   'selling_price': 175000,
#   'km_driven': 78380,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Renault Duster 110PS Diesel RxZ',
#   'year': 2012,
#   'selling_price': 434999,
#   'km_driven': 110000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Ford Figo Diesel Titanium',
#   'year': 2010,
#   'selling_price': 170000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Ford Figo Diesel Titanium',
#   'year': 2011,
#   'selling_price': 190000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Maruti Swift Dzire VDi',
#   'year': 2009,
#   'selling_price': 250000,
#   'km_driven': 150000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Mahindra Xylo E4',
#   'year': 2009,
#   'selling_price': 229999,
#   'km_driven': 230000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Maruti Esteem Vxi - BSIII',
#   'year': 2006,
#   'selling_price': 140000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Maruti Swift VDI BSIV',
#   'year': 2017,
#   'selling_price': 600000,
#   'km_driven': 80362,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 1.2 Sportz',
#   'year': 2012,
#   'selling_price': 280000,
#   'km_driven': 110000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Chevrolet Beat Diesel LT',
#   'year': 2012,
#   'selling_price': 150000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Cruze LTZ AT',
#   'year': 2015,
#   'selling_price': 650000,
#   'km_driven': 50000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Nissan Micra XL',
#   'year': 2014,
#   'selling_price': 210000,
#   'km_driven': 40000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'BMW 5 Series 520d Luxury Line',
#   'year': 2017,
#   'selling_price': 2900000,
#   'km_driven': 40000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Enjoy 1.3 TCDi LS 8',
#   'year': 2013,
#   'selling_price': 425000,
#   'km_driven': 20000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Era Plus Option',
#   'year': 2014,
#   'selling_price': 265000,
#   'km_driven': 55000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Fiat Linea T Jet Emotion',
#   'year': 2018,
#   'selling_price': 890000,
#   'km_driven': 1136,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Renault Scala RxL',
#   'year': 2013,
#   'selling_price': 365000,
#   'km_driven': 55000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Ford Figo Petrol Titanium',
#   'year': 2014,
#   'selling_price': 350000,
#   'km_driven': 43000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ciaz ZDi SHVS',
#   'year': 2016,
#   'selling_price': 685000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Skoda Rapid 1.5 TDI Ambition BSIV',
#   'year': 2018,
#   'selling_price': 940000,
#   'km_driven': 2650,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra XUV500 W6 2WD',
#   'year': 2017,
#   'selling_price': 1000000,
#   'km_driven': 40000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra XUV300 W8 Option',
#   'year': 2019,
#   'selling_price': 1150000,
#   'km_driven': 15000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ertiga SHVS ZDI',
#   'year': 2016,
#   'selling_price': 450000,
#   'km_driven': 115962,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Nissan Terrano XE D',
#   'year': 2015,
#   'selling_price': 590000,
#   'km_driven': 65000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti S-Cross Facelift',
#   'year': 2017,
#   'selling_price': 800000,
#   'km_driven': 40000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 Magna 1.4 CRDi (Diesel)',
#   'year': 2012,
#   'selling_price': 385000,
#   'km_driven': 58000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mercedes-Benz New C-Class C 220 CDI BE Avantgare',
#   'year': 2013,
#   'selling_price': 2000000,
#   'km_driven': 15000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Era Plus',
#   'year': 2012,
#   'selling_price': 235000,
#   'km_driven': 54000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Volkswagen Ameo 1.5 TDI Highline',
#   'year': 2017,
#   'selling_price': 640000,
#   'km_driven': 56000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto LX',
#   'year': 2006,
#   'selling_price': 52000,
#   'km_driven': 120000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Maruti Omni LPG CARGO BSIII W IMMOBILISER',
#   'year': 2009,
#   'selling_price': 80000,
#   'km_driven': 90000,
#   'fuel': 'LPG',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Alto LX',
#   'year': 2012,
#   'selling_price': 140000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Verna i (Petrol)',
#   'year': 2008,
#   'selling_price': 120000,
#   'km_driven': 90000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Mahindra Renault Logan 1.5 DLS',
#   'year': 2008,
#   'selling_price': 89999,
#   'km_driven': 213000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Optra Magnum 2.0 LS BSIII',
#   'year': 2012,
#   'selling_price': 180000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio S11 BSIV',
#   'year': 2017,
#   'selling_price': 1500000,
#   'km_driven': 20000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 Active 1.2 SX',
#   'year': 2017,
#   'selling_price': 700000,
#   'km_driven': 10000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
# ...
#   'year': 2015,
#   'selling_price': 625000,
#   'km_driven': 11918,
#   'fuel': 'Petrol',
#   'seller_type': 'Trustmark Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Grand i10 Magna AT',
#   'year': 2017,
#   'selling_price': 520000,
#   'km_driven': 10510,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Beat LT Option',
#   'year': 2016,
#   'selling_price': 239000,
#   'km_driven': 41000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Fortuner 4x2 AT',
#   'year': 2017,
#   'selling_price': 2600000,
#   'km_driven': 47162,
#   'fuel': 'Diesel',
#   'seller_type': 'Trustmark Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti S-Cross Zeta DDiS 200 SH',
#   'year': 2015,
#   'selling_price': 750000,
#   'km_driven': 45974,
#   'fuel': 'Diesel',
#   'seller_type': 'Trustmark Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i10 Magna',
#   'year': 2012,
#   'selling_price': 229999,
#   'km_driven': 49824,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Audi A6 2.0 TDI Premium Plus',
#   'year': 2013,
#   'selling_price': 1300000,
#   'km_driven': 58500,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro GS',
#   'year': 2005,
#   'selling_price': 80000,
#   'km_driven': 56580,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Skoda Laura Ambiente 2.0 TDI CR MT',
#   'year': 2012,
#   'selling_price': 385000,
#   'km_driven': 52000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Verna 1.6 VTVT SX',
#   'year': 2015,
#   'selling_price': 760000,
#   'km_driven': 55340,
#   'fuel': 'Petrol',
#   'seller_type': 'Trustmark Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift Dzire VDI',
#   'year': 2017,
#   'selling_price': 600000,
#   'km_driven': 46507,
#   'fuel': 'Diesel',
#   'seller_type': 'Trustmark Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Volkswagen Jetta 2.0L TDI Highline AT',
#   'year': 2012,
#   'selling_price': 735000,
#   'km_driven': 55300,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Tata Indica Vista Quadrajet 90 VX',
#   'year': 2012,
#   'selling_price': 285000,
#   'km_driven': 74300,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda City VX MT',
#   'year': 2010,
#   'selling_price': 350000,
#   'km_driven': 48781,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Volkswagen Jetta 1.9 Highline TDI',
#   'year': 2010,
#   'selling_price': 290000,
#   'km_driven': 87620,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Volkswagen Vento 1.5 TDI Highline Plus AT',
#   'year': 2017,
#   'selling_price': 890000,
#   'km_driven': 40219,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Honda Jazz VX',
#   'year': 2011,
#   'selling_price': 385000,
#   'km_driven': 11473,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Eeco 5 Seater AC BSIV',
#   'year': 2017,
#   'selling_price': 425000,
#   'km_driven': 8352,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Wagon R VXI AMT1.2BSIV',
#   'year': 2017,
#   'selling_price': 525000,
#   'km_driven': 9745,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Grand i10 Asta',
#   'year': 2017,
#   'selling_price': 550000,
#   'km_driven': 9748,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Volkswagen Polo 1.0 MPI Trendline',
#   'year': 2012,
#   'selling_price': 271000,
#   'km_driven': 49000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Creta 1.6 CRDi SX Option',
#   'year': 2018,
#   'selling_price': 1490000,
#   'km_driven': 20694,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Grand i10 Asta Option',
#   'year': 2015,
#   'selling_price': 490000,
#   'km_driven': 31080,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Era Plus',
#   'year': 2014,
#   'selling_price': 260000,
#   'km_driven': 37605,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Xcent 1.1 CRDi SX Option',
#   'year': 2014,
#   'selling_price': 455000,
#   'km_driven': 55850,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Nano Lx BSIV',
#   'year': 2010,
#   'selling_price': 75000,
#   'km_driven': 58850,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Etios Cross 1.2L G',
#   'year': 2015,
#   'selling_price': 421000,
#   'km_driven': 23839,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift DDiS LDI',
#   'year': 2016,
#   'selling_price': 550000,
#   'km_driven': 54000,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i10 Sportz 1.2 AT',
#   'year': 2013,
#   'selling_price': 330000,
#   'km_driven': 38000,
#   'fuel': 'Petrol',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Volkswagen Vento 1.5 TDI Comfortline',
#   'year': 2012,
#   'selling_price': 390000,
#   'km_driven': 45454,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Skoda Rapid 1.5 TDI AT Ambition',
#   'year': 2015,
#   'selling_price': 599000,
#   'km_driven': 46957,
#   'fuel': 'Diesel',
#   'seller_type': 'Dealer',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Getz GLE',
#   'year': 2007,
#   'selling_price': 110000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Renault KWID RXT Optional',
#   'year': 2016,
#   'selling_price': 250000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio M2DI',
#   'year': 2012,
#   'selling_price': 600000,
#   'km_driven': 110000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Ford Endeavour XLT TDCi 4X2',
#   'year': 2008,
#   'selling_price': 280000,
#   'km_driven': 190000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Audi Q3 35 TDI Quattro Technology',
#   'year': 2018,
#   'selling_price': 2700000,
#   'km_driven': 25000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Renault Logan 1.4 GLX Petrol',
#   'year': 2008,
#   'selling_price': 80000,
#   'km_driven': 90000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto K10 VXI',
#   'year': 2019,
#   'selling_price': 350000,
#   'km_driven': 5000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift VDI BSIV',
#   'year': 2015,
#   'selling_price': 475000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Audi A5 Sportback',
#   'year': 2020,
#   'selling_price': 4700000,
#   'km_driven': 1500,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift Dzire VDI',
#   'year': 2018,
#   'selling_price': 500000,
#   'km_driven': 50000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Chevrolet Sail Hatchback 1.3 TCDi LT ABS',
#   'year': 2014,
#   'selling_price': 250000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Accent CRDi',
#   'year': 2005,
#   'selling_price': 100000,
#   'km_driven': 120000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Alto K10 VXI Airbag',
#   'year': 2019,
#   'selling_price': 350000,
#   'km_driven': 5000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'BMW 7 Series Signature 730Ld',
#   'year': 2014,
#   'selling_price': 4000000,
#   'km_driven': 47000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Camry 2.5 Hybrid',
#   'year': 2017,
#   'selling_price': 1900000,
#   'km_driven': 20000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro Xing XG',
#   'year': 2005,
#   'selling_price': 95000,
#   'km_driven': 120000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Grand i10 CRDi Sportz',
#   'year': 2015,
#   'selling_price': 409999,
#   'km_driven': 58000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra XUV500 W5 BSIV',
#   'year': 2018,
#   'selling_price': 1050000,
#   'km_driven': 35000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto K10 VXI',
#   'year': 2017,
#   'selling_price': 320000,
#   'km_driven': 30000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra XUV300 W8 Option Diesel BSIV',
#   'year': 2019,
#   'selling_price': 1000000,
#   'km_driven': 10000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Toyota Innova Crysta 2.4 VX MT BSIV',
#   'year': 2017,
#   'selling_price': 1770000,
#   'km_driven': 25000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Thar CRDe',
#   'year': 2018,
#   'selling_price': 950000,
#   'km_driven': 20000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Swift Dzire ZDI',
#   'year': 2018,
#   'selling_price': 750000,
#   'km_driven': 50000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai EON Magna Plus',
#   'year': 2014,
#   'selling_price': 220000,
#   'km_driven': 42000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Tata Hexa XM',
#   'year': 2017,
#   'selling_price': 1000000,
#   'km_driven': 50000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Honda Mobilio E i DTEC',
#   'year': 2017,
#   'selling_price': 660000,
#   'km_driven': 116000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ertiga ZDI',
#   'year': 2015,
#   'selling_price': 716000,
#   'km_driven': 100000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Ciaz ZXi Plus',
#   'year': 2015,
#   'selling_price': 675000,
#   'km_driven': 66000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio LX',
#   'year': 2010,
#   'selling_price': 385000,
#   'km_driven': 110000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Fiat Grande Punto EVO 1.3 Dynamic',
#   'year': 2014,
#   'selling_price': 325000,
#   'km_driven': 70000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Creta 1.6 CRDi SX Option',
#   'year': 2015,
#   'selling_price': 950000,
#   'km_driven': 60000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Ford Endeavour Hurricane Limited Edition',
#   'year': 2007,
#   'selling_price': 400000,
#   'km_driven': 110000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'Fourth & Above Owner'},
#  {'name': 'Tata Indica Vista TDI LS',
#   'year': 2014,
#   'selling_price': 250000,
#   'km_driven': 25000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Land Rover Discovery S 2.0 SD4',
#   'year': 2018,
#   'selling_price': 4000000,
#   'km_driven': 68000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'First Owner'},
#  {'name': 'Maruti Alto 800 LXI',
#   'year': 2014,
#   'selling_price': 210000,
#   'km_driven': 20000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i10 Era 1.1 iTech SE',
#   'year': 2011,
#   'selling_price': 147000,
#   'km_driven': 110000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Maruti Vitara Brezza VDi Option',
#   'year': 2018,
#   'selling_price': 725000,
#   'km_driven': 26350,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Mahindra Scorpio SLE BSIV',
#   'year': 2012,
#   'selling_price': 550000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai i20 Sportz Option 1.2',
#   'year': 2016,
#   'selling_price': 475000,
#   'km_driven': 25000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Santro Xing GLS',
#   'year': 2014,
#   'selling_price': 250000,
#   'km_driven': 50000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Tata Indica LSI',
#   'year': 2006,
#   'selling_price': 70000,
#   'km_driven': 60000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai EON Era Plus',
#   'year': 2012,
#   'selling_price': 160000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'Third Owner'},
#  {'name': 'Ford Endeavour 3.0L 4X4 AT',
#   'year': 2011,
#   'selling_price': 1000000,
#   'km_driven': 90000,
#   'fuel': 'Diesel',
#   'seller_type': 'Individual',
#   'transmission': 'Automatic',
#   'owner': 'Second Owner'},
#  {'name': 'Hyundai Santro LE zipPlus',
#   'year': 2001,
#   'selling_price': 68000,
#   'km_driven': 70000,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  {'name': 'Hyundai Grand i10 1.2 Kappa Asta',
#   'year': 2017,
#   'selling_price': 500000,
#   'km_driven': 26500,
#   'fuel': 'Petrol',
#   'seller_type': 'Individual',
#   'transmission': 'Manual',
#   'owner': 'First Owner'},
#  ...]

# %% [markdown]
# #Uploading data in Mongodb

# %%
import pymongo
from pymongo import MongoClient
#mongo client is connected
client = MongoClient()
db     = client['cardata']

# %%
rhostName = 'rs0/n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017'   # place your own credentials here
ruserName = 'u6xxnzcbuooqbdjoxb1l'      # place your own credentials here
rpassWord = 'Zi1ednmMWrj60RW4Ld0U'      # place your own credentials here
rdbName =  'bl49unurvjeqngy'         # place your own credentials here
rMongoURI = 'mongodb://ugaoamztcc4gww93dkqi:Zi1ednmMWrj60RW4Ld0U@n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017/bl49unurvjeqngy?replicaSet=rs0' 

print(rhostName,ruserName,rdbName)
print(rMongoURI)
# Out:
# rs0/n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017 u6xxnzcbuooqbdjoxb1l bl49unurvjeqngy
# mongodb://ugaoamztcc4gww93dkqi:Zi1ednmMWrj60RW4Ld0U@n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017/bl49unurvjeqngy?replicaSet=rs0

# %%
mongoURI = rMongoURI                                   # for remote server
#mongoURI = "mongodb://localhost:27017/"                 # for local server
client = MongoClient(mongoURI)
client.list_database_names() # ['admin', 'local']
# Out:
# ['bl49unurvjeqngy']

# %%
#db = client.PraxisDB
db = client.bl49unurvjeqngy
db.list_collection_names()
# Out:
# ['unece', 'cardata']

# %%
table = db.cardata
table.count_documents({})
# Out:
# 4340

# %%
# Delete collection
db.drop_collection('cardata')
# Out:
# {'ns': 'bl49unurvjeqngy.cardata',
#  'nIndexesWas': 1,
#  'ok': 1.0,
#  'operationTime': Timestamp(1673993535, 10),
#  '$clusterTime': {'clusterTime': Timestamp(1673993535, 10),
#   'signature': {'hash': b'O\xfe\x04hA"\xe5\x8a\xafD7\xc8\x80\x0ft\x9bFB\xaa{',
#    'keyId': 7146300907339120641}}}

# %%
#db = client.PraxisDB
db = client.bl49unurvjeqngy
db.list_collection_names()
# Out:
# ['unece']

# %% [markdown]
# #Inserting data in Mongodb

# %%
db.cardata.insert_many(data)

# %%
#db = client.PraxisDB
db = client.bl49unurvjeqngy
db.list_collection_names()
# Out:
# ['unece', 'cardata']

# %%
xy=db.cardata

# %%
yz=db.cardata.find()

# %%
list_cursor=list(yz)

# %%
print(list_cursor)
# Out:
# [{'_id': ObjectId('63c71d3f9770995a5460ecf0'), 'name': 'Maruti 800 AC', 'year': 2007, 'selling_price': 60000, 'km_driven': 70000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf1'), 'name': 'Maruti Wagon R LXI Minor', 'year': 2007, 'selling_price': 135000, 'km_driven': 50000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf2'), 'name': 'Hyundai Verna 1.6 SX', 'year': 2012, 'selling_price': 600000, 'km_driven': 100000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf3'), 'name': 'Datsun RediGO T Option', 'year': 2017, 'selling_price': 250000, 'km_driven': 46000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf4'), 'name': 'Honda Amaze VX i-DTEC', 'year': 2014, 'selling_price': 450000, 'km_driven': 141000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'Second Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf5'), 'name': 'Maruti Alto LX BSIII', 'year': 2007, 'selling_price': 140000, 'km_driven': 125000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf6'), 'name': 'Hyundai Xcent 1.2 Kappa S', 'year': 2016, 'selling_price': 550000, 'km_driven': 25000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf7'), 'name': 'Tata Indigo Grand Petrol', 'year': 2014, 'selling_price': 240000, 'km_driven': 60000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'Second Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf8'), 'name': 'Hyundai Creta 1.6 VTVT S', 'year': 2015, 'selling_price': 850000, 'km_driven': 25000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecf9'), 'name': 'Maruti Celerio Green VXI', 'year': 2017, 'selling_price': 365000, 'km_driven': 78000, 'fuel': 'CNG', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecfa'), 'name': 'Chevrolet Sail 1.2 Base', 'year': 2015, 'selling_price': 260000, 'km_driven': 35000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecfb'), 'name': 'Tata Indigo Grand Petrol', 'year': 2014, 'selling_price': 250000, 'km_driven': 100000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecfc'), 'name': 'Toyota Corolla Altis 1.8 VL CVT', 'year': 2018, 'selling_price': 1650000, 'km_driven': 25000, 'fuel': 'Petrol', 'seller_type': 'Dealer', 'transmission': 'Automatic', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecfd'), 'name': 'Maruti 800 AC', 'year': 2007, 'selling_price': 60000, 'km_driven': 70000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecfe'), 'name': 'Maruti Wagon R LXI Minor', 'year': 2007, 'selling_price': 135000, 'km_driven': 50000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ecff'), 'name': 'Hyundai Verna 1.6 SX', 'year': 2012, 'selling_price': 600000, 'km_driven': 100000, 'fuel': 'Diesel', 'seller_type': 'Individual', 'transmission': 'Manual', 'owner': 'First Owner'}, {'_id': ObjectId('63c71d3f9770995a5460ed00'), 'name': 'Datsun RediGO T Option', 'year': 2017, 'selling_price': 250000, 'km_driven': 46000, 'fuel': 'Petrol', 'seller_type': 'Individual', 'transmission': 'Ma ...

# %% [markdown]
# #Converting data into Pandas Dataframe

# %%
yz=pd.DataFrame(list_cursor)

# %%
yz.head()
# Out:
#                         _id                      name  year  selling_price  \
# 0  63c71d3f9770995a5460ecf0             Maruti 800 AC  2007          60000
# 1  63c71d3f9770995a5460ecf1  Maruti Wagon R LXI Minor  2007         135000
# 2  63c71d3f9770995a5460ecf2      Hyundai Verna 1.6 SX  2012         600000
# 3  63c71d3f9770995a5460ecf3    Datsun RediGO T Option  2017         250000
# 4  63c71d3f9770995a5460ecf4     Honda Amaze VX i-DTEC  2014         450000
#
#    km_driven    fuel seller_type transmission         owner
# 0      70000  Petrol  Individual       Manual   First Owner
# 1      50000  Petrol  Individual       Manual   First Owner
# 2     100000  Diesel  Individual       Manual   First Owner
# 3      46000  Petrol  Individual       Manual   First Owner
# 4     141000  Diesel  Individual       Manual  Second Owner

# %% [markdown]
# #Install

# %%
# !pip3 -q install pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Praxis').getOrCreate()

# %%
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.sql.types import * 
import pyspark.sql.functions as F
from pyspark.sql.functions import col, asc,desc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pyspark.sql import SQLContext
from pyspark.mllib.stat import Statistics
import pandas as pd
from pyspark.sql.functions import udf
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler,StandardScaler
from pyspark.ml import Pipeline
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #Converting Mongodb data to spark dataframe

# %%
ls
# Out:
# CAR_DETAILS_FROM_CAR_DEKHO.csv    Data_Set.csv
# CAR_DETAILS_FROM_CAR_DEKHO.csv.1  sample_data/
# CAR_DETAILS_FROM_CAR_DEKHO.csv.2

# %% [markdown]
# SCHEMA FOR SPARK TABLE

# %%
schema='{"fields":[{"metadata":{},"name":"selling_price","nullable":true,"type":"long"},{"metadata":{},"name":"km_driven","nullable":true,"type":"long"},{"metadata":{},"name":"year_of_service","nullable":true,"type":"long"},{"metadata":{"ml_attr":{"name":"fuel_indexer","type":"nominal","vals":["Diesel","Petrol","CNG","LPG"]}},"name":"fuel_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"Diesel"},{"idx":1,"name":"Petrol"},{"idx":2,"name":"CNG"}]},"num_attrs":3}},"name":"fuel_Vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"name":"seller_type_indexer","type":"nominal","vals":["Individual","Dealer","Trustmark Dealer"]}},"name":"seller_type_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"Individual"},{"idx":1,"name":"Dealer"}]},"num_attrs":2}},"name":"seller_type_vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"name":"owner_indexer","type":"nominal","vals":["First Owner","Second Owner","Third Owner","Fourth & Above Owner","Test Drive Car"]}},"name":"owner_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"First Owner"},{"idx":1,"name":"Second Owner"},{"idx":2,"name":"Third Owner"},{"idx":3,"name":"Fourth & Above Owner"}]},"num_attrs":4}},"name":"owner_vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"name":"transmission_indexer","type":"nominal","vals":["Manual","Automatic"]}},"name":"transmission_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"Manual"}]},"num_attrs":1}},"name":"transmission_vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":2,"name":"fuel_Vector_Diesel"},{"idx":3,"name":"fuel_Vector_Petrol"},{"idx":4,"name":"fuel_Vector_CNG"},{"idx":5,"name":"seller_type_vector_Individual"},{"idx":6,"name":"seller_type_vector_Dealer"},{"idx":7,"name":"owner_vector_First Owner"},{"idx":8,"name":"owner_vector_Second Owner"},{"idx":9,"name":"owner_vector_Third Owner"},{"idx":10,"name":"owner_vector_Fourth & Above Owner"},{"idx":11,"name":"transmission_vector_Manual"}],"numeric":[{"idx":0,"name":"km_driven"},{"idx":1,"name":"year_of_service"}]},"num_attrs":12}},"name":"features","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}}],"type":"struct"}'

# %%
new_schema = StructType.fromJson(json.loads(schema))

# %% [markdown]
# #Load Data

# %%
# !wget -O Data_Set.csv -q https://raw.githubusercontent.com/Praxis-QR/BDSN/main/Documents/CustomerConversion_GG.csv

# %%
# Load and Read the dataset
data=spark.read.csv('CAR_DETAILS_FROM_CAR_DEKHO.csv',inferSchema=True,header=True)

# %%
# Chech the datatypes of the inputs
data.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- selling_price: integer (nullable = true)
#  |-- km_driven: integer (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- seller_type: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- owner: string (nullable = true)

# %% [markdown]
# #Data Exploration

# %%
data.count(), len(data.columns)
# Out:
# (4340, 8)

# %%
data.dtypes
# Out:
# [('name', 'string'),
#  ('year', 'int'),
#  ('selling_price', 'int'),
#  ('km_driven', 'int'),
#  ('fuel', 'string'),
#  ('seller_type', 'string'),
#  ('transmission', 'string'),
#  ('owner', 'string')]

# %%
data.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- selling_price: integer (nullable = true)
#  |-- km_driven: integer (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- seller_type: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- owner: string (nullable = true)

# %%
data.count()
# Out:
# 4340

# %%
data.columns
# Out:
# ['name',
#  'year',
#  'selling_price',
#  'km_driven',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner']

# %%
data.describe().show()
# Out:
# +-------+--------------------+------------------+-----------------+-----------------+------+----------------+------------+-----------+
# |summary|                name|              year|    selling_price|        km_driven|  fuel|     seller_type|transmission|      owner|
# +-------+--------------------+------------------+-----------------+-----------------+------+----------------+------------+-----------+
# |  count|                4340|              4340|             4340|             4340|  4340|            4340|        4340|       4340|
# |   mean|                null|2013.0907834101383|504127.3117511521|66215.77741935484|  null|            null|        null|       null|
# | stddev|                null| 4.215343939724156|578548.7361388858|46644.10219362085|  null|            null|        null|       null|
# |    min|Ambassador CLASSI...|              1992|            20000|                1|   CNG|          Dealer|   Automatic|First Owner|
# |    max|Volvo XC60 D5 Ins...|              2020|          8900000|           806599|Petrol|Trustmark Dealer|      Manual|Third Owner|
# +-------+--------------------+------------------+-----------------+-----------------+------+----------------+------------+-----------+

# %%
for col in data.columns:
  print(col, "has", data.filter(data[col].isNull()).count(), "Null values.")
# Out:
# name has 0 Null values.
# year has 0 Null values.
# selling_price has 0 Null values.
# km_driven has 0 Null values.
# fuel has 0 Null values.
# seller_type has 0 Null values.
# transmission has 0 Null values.
# owner has 0 Null values.

# %%
data.groupBy("fuel").count().sort("fuel").show()
# Out:
# +--------+-----+
# |    fuel|count|
# +--------+-----+
# |     CNG|   40|
# |  Diesel| 2153|
# |Electric|    1|
# |     LPG|   23|
# |  Petrol| 2123|
# +--------+-----+

# %% [markdown]
# As the number of instance with 'Electric' as fuel is only 1 so we can't keep it because it won't help in random split of the data because this instance will either in train set or test set. So after training the model it will create problem for prediction

# %%
# Checking for the instance where the fuel is 'Electric'
data.where(data.fuel == 'Electric').show()
# Out:
# +-------------------+----+-------------+---------+--------+-----------+------------+------------+
# |               name|year|selling_price|km_driven|    fuel|seller_type|transmission|       owner|
# +-------------------+----+-------------+---------+--------+-----------+------------+------------+
# |Toyota Camry Hybrid|2006|       310000|    62000|Electric|     Dealer|   Automatic|Second Owner|
# +-------------------+----+-------------+---------+--------+-----------+------------+------------+

# %% [markdown]
# Creating a new dataframe where all the instances will be present except Electric fuel. This data frame will be used now onwards

# %%
new_data = data.filter((data.fuel != "Electric"))
  
new_data.show()
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+------------+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual| First Owner|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual| First Owner|
# |Tata Indigo Grand...|2014|       240000|    60000|Petrol| Individual|      Manual|Second Owner|
# |Hyundai Creta 1.6...|2015|       850000|    25000|Petrol| Individual|      Manual| First Owner|
# |Maruti Celerio Gr...|2017|       365000|    78000|   CNG| Individual|      Manual| First Owner|
# |Chevrolet Sail 1....|2015|       260000|    35000|Petrol| Individual|      Manual| First Owner|
# |Tata Indigo Grand...|2014|       250000|   100000|Petrol| Individual|      Manual| First Owner|
# |Toyota Corolla Al...|2018|      1650000|    25000|Petrol|     Dealer|   Automatic| First Owner|
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual| First Owner|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual| First Owner|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *

# %% [markdown]
# Some Preprocessing with 'year' column as apurpose for EDA. Adding a column year_of_service by sbtracting the given year from the current year

# %%
new_data = new_data.withColumn("current_year",year(current_date()))
#new_data = new_data.withcolumn("")
new_data.show()
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|current_year|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|        2023|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|        2023|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|        2023|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|        2023|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual| First Owner|        2023|
# |Tata Indigo Grand...|2014|       240000|    60000|Petrol| Individual|      Manual|Second Owner|        2023|
# |Hyundai Creta 1.6...|2015|       850000|    25000|Petrol| Individual|      Manual| First Owner|        2023|
# |Maruti Celerio Gr...|2017|       365000|    78000|   CNG| Individual|      Manual| First Owner|        2023|
# |Chevrolet Sail 1....|2015|       260000|    35000|Petrol| Individual|      Manual| First Owner|        2023|
# |Tata Indigo Grand...|2014|       250000|   100000|Petrol| Individual|      Manual| First Owner|        2023|
# |Toyota Corolla Al...|2018|      1650000|    25000|Petrol|     Dealer|   Automatic| First Owner|        2023|
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|        2023|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|        2023|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|        2023|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|        2023|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual| First Owner|        2023|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+
# only showing top 20 rows

# %%
new_data.dtypes
# Out:
# [('name', 'string'),
#  ('year', 'int'),
#  ('selling_price', 'int'),
#  ('km_driven', 'int'),
#  ('fuel', 'string'),
#  ('seller_type', 'string'),
#  ('transmission', 'string'),
#  ('owner', 'string'),
#  ('current_year', 'int')]

# %%
new_data = new_data.withColumn("year_of_service",new_data.current_year - new_data.year)
new_data.show(5)
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|current_year|year_of_service|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|        2023|              9|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# only showing top 5 rows

# %%
new_data.count(), len(new_data.columns)
# Out:
# (4339, 10)

# %% [markdown]
# Rechecking for the 'Electric' fuel instance in this new dataframe

# %%
new_data.where(new_data.fuel == 'Electric').show()
# Out:
# +----+----+-------------+---------+----+-----------+------------+-----+------------+---------------+
# |name|year|selling_price|km_driven|fuel|seller_type|transmission|owner|current_year|year_of_service|
# +----+----+-------------+---------+----+-----------+------------+-----+------------+---------------+
# +----+----+-------------+---------+----+-----------+------------+-----+------------+---------------+

# %%
new_data.groupBy("seller_type").count().sort("seller_type",ascending=True).show()
# Out:
# +----------------+-----+
# |     seller_type|count|
# +----------------+-----+
# |          Dealer|  993|
# |      Individual| 3244|
# |Trustmark Dealer|  102|
# +----------------+-----+

# %%
new_data.groupBy("transmission").count().sort("transmission",ascending=True).show()
# Out:
# +------------+-----+
# |transmission|count|
# +------------+-----+
# |   Automatic|  447|
# |      Manual| 3892|
# +------------+-----+

# %%
new_data.groupBy("owner").count().sort("owner",ascending=True).show()
# Out:
# +--------------------+-----+
# |               owner|count|
# +--------------------+-----+
# |         First Owner| 2832|
# |Fourth & Above Owner|   81|
# |        Second Owner| 1105|
# |      Test Drive Car|   17|
# |         Third Owner|  304|
# +--------------------+-----+

# %%
new_data.groupBy("name").count().sort("name",ascending=True).show()
# Out:
# +--------------------+-----+
# |                name|count|
# +--------------------+-----+
# |Ambassador CLASSI...|    2|
# |Ambassador Classi...|    1|
# |Ambassador Grand ...|    1|
# |    Audi A4 1.8 TFSI|    1|
# |     Audi A4 2.0 TDI|    1|
# |Audi A4 2.0 TDI 1...|    2|
# |Audi A4 3.0 TDI Q...|   12|
# |Audi A4 30 TFSI T...|    2|
# |Audi A4 35 TDI Pr...|    1|
# |Audi A4 35 TDI Pr...|    1|
# |Audi A4 New  2.0 ...|    1|
# |   Audi A5 Sportback|    1|
# |Audi A6 2.0 TDI  ...|    3|
# |Audi A6 2.0 TDI P...|   13|
# |     Audi A6 2.7 TDI|    1|
# |     Audi A6 2.8 FSI|    1|
# |     Audi A8 4.2 TDI|    2|
# |Audi A8 L 3.0 TDI...|    1|
# |Audi Q3 2.0 TDI Q...|    4|
# |Audi Q3 35 TDI Qu...|    2|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# Showing group wise average selling_price

# %%
new_data.groupBy('owner').mean('selling_price','km_driven').show()
# Out:
# +--------------------+------------------+------------------+
# |               owner|avg(selling_price)|    avg(km_driven)|
# +--------------------+------------------+------------------+
# |         Third Owner| 269474.0032894737| 99304.50657894737|
# |Fourth & Above Owner|173901.19753086418| 99138.13580246913|
# |        Second Owner|343921.75927601807| 81801.42262443439|
# |         First Owner| 598636.9696327683|56015.009887005646|
# |      Test Drive Car| 954293.9411764706|            4155.0|
# +--------------------+------------------+------------------+

# %%
new_data.groupBy('transmission').mean('selling_price','km_driven').show()
# Out:
# +------------+------------------+-----------------+
# |transmission|avg(selling_price)|   avg(km_driven)|
# +------------+------------------+-----------------+
# |   Automatic| 1410610.720357942|49661.26174496644|
# |      Manual| 400066.6857656732|68118.16289825282|
# +------------+------------------+-----------------+

# %%
new_data.groupBy('fuel').mean('selling_price','km_driven').show()
# Out:
# +------+------------------+-----------------+
# |  fuel|avg(selling_price)|   avg(km_driven)|
# +------+------------------+-----------------+
# |Diesel| 669094.2522062239|79630.97770552717|
# |   CNG|        277174.925|         67234.75|
# |   LPG|167826.04347826086|89634.78260869565|
# |Petrol| 344840.1375412153|52340.07960433349|
# +------+------------------+-----------------+

# %%
new_data.groupBy('year').mean('selling_price','km_driven').show()
# Out:
# +----+------------------+------------------+
# |year|avg(selling_price)|    avg(km_driven)|
# +----+------------------+------------------+
# |2003| 86565.21739130435| 81671.34782608696|
# |2007|162828.35074626867| 89308.67910447762|
# |2018| 910770.4590163934|27233.784153005465|
# |2015| 528942.9548693587| 60585.20665083135|
# |2006| 156403.6146788991|102976.39449541284|
# |2013| 484801.0129533679| 72728.42227979275|
# |1997|           93000.0|           90000.0|
# |2014| 523231.5640326975| 75685.27247956404|
# |2019| 1059020.482051282|20912.476923076923|
# |2004|121749.97619047618| 90273.30952380953|
# |1996|          225000.0|           47500.0|
# |1998|          214000.0|64583.333333333336|
# |2020|        818479.125|11037.166666666666|
# |2012| 371628.8530120482| 83393.55421686747|
# |2009|229564.73575129535| 92521.28497409326|
# |2016| 608364.0924369748| 55205.90476190476|
# |1995|           95000.0|          100000.0|
# |2001|          117649.9|          83712.85|
# |1992|           50000.0|          100000.0|
# |2005|109013.02352941176| 80991.51764705882|
# +----+------------------+------------------+
# only showing top 20 rows

# %%
new_data.groupBy('year_of_service').mean('selling_price','km_driven').show()
# Out:
# +---------------+------------------+------------------+
# |year_of_service|avg(selling_price)|    avg(km_driven)|
# +---------------+------------------+------------------+
# |             31|           50000.0|          100000.0|
# |             28|           95000.0|          100000.0|
# |             27|          225000.0|           47500.0|
# |             26|           93000.0|           90000.0|
# |             12|293638.33210332104| 88096.28782287824|
# |             22|          117649.9|          83712.85|
# |             13| 269678.1282051282| 91735.43589743589|
# |             16|162828.35074626867| 89308.67910447762|
# |              6|  768909.839055794| 40485.76394849786|
# |              3|        818479.125|11037.166666666666|
# |             20| 86565.21739130435| 81671.34782608696|
# |              5| 910770.4590163934|27233.784153005465|
# |             19|121749.97619047618| 90273.30952380953|
# |             15|174201.33103448275| 89163.11724137931|
# |              9| 523231.5640326975| 75685.27247956404|
# |             17| 156403.6146788991|102976.39449541284|
# |              4| 1059020.482051282|20912.476923076923|
# |              8| 528942.9548693587| 60585.20665083135|
# |             23|           81500.0| 70936.91666666667|
# |              7| 608364.0924369748| 55205.90476190476|
# +---------------+------------------+------------------+
# only showing top 20 rows

# %%
import pandas as pd
import numpy as np

# %%
DF = new_data.toPandas()

# %%
DF.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  current_year  year_of_service
# 0  Individual       Manual   First Owner          2023               16
# 1  Individual       Manual   First Owner          2023               16
# 2  Individual       Manual   First Owner          2023               11
# 3  Individual       Manual   First Owner          2023                6
# 4  Individual       Manual  Second Owner          2023                9

# %%
DF = DF.set_index('name')

# %%
DF.head()
# Out:
#                           year  selling_price  km_driven    fuel seller_type  \
# name
# Maruti 800 AC             2007          60000      70000  Petrol  Individual
# Maruti Wagon R LXI Minor  2007         135000      50000  Petrol  Individual
# Hyundai Verna 1.6 SX      2012         600000     100000  Diesel  Individual
# Datsun RediGO T Option    2017         250000      46000  Petrol  Individual
# Honda Amaze VX i-DTEC     2014         450000     141000  Diesel  Individual
#
#                          transmission         owner  current_year  \
# name
# Maruti 800 AC                  Manual   First Owner          2023
# Maruti Wagon R LXI Minor       Manual   First Owner          2023
# Hyundai Verna 1.6 SX           Manual   First Owner          2023
# Datsun RediGO T Option         Manual   First Owner          2023
# Honda Amaze VX i-DTEC          Manual  Second Owner          2023
#
#                           year_of_service
# name
# Maruti 800 AC                          16
# Maruti Wagon R LXI Minor               16
# Hyundai Verna 1.6 SX                   11
# Datsun RediGO T Option                  6
# Honda Amaze VX i-DTEC                   9

# %%
cor = DF.corr()

# %%
cor.selling_price.sort_values(ascending=False)
# Out:
# selling_price      1.000000
# year               0.413932
# km_driven         -0.192298
# year_of_service   -0.413932
# current_year            NaN
# Name: selling_price, dtype: float64

# %% [markdown]
# As we found that there we few instances of name with 1 or 2 values only, so that would create a problem while training and testing as after the random sampling and splitting those single instances would either go to train set or test set. So, we are converting this 'name' column to the index for this dataframe

# %% [markdown]
# We can do some graph plotting using this pandas dataframe for our ease of work

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(x=DF['km_driven'], bins=20, kde=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x='km_driven',data=DF)

# %%
sns.boxplot(x='year_of_service', data=DF)

# %%
DF['km_driven'].plot(kind='hist', bins=25)

# %%
sns.regplot(x='year', y='selling_price', data=DF)

# %%
plt.figure()
DF.groupby('year')['selling_price'].mean().plot(kind='bar')

# %%
sns.regplot(x='year_of_service', y='selling_price', data=DF)

# %% [markdown]
# It shows that with increasing year the selling price of a car has been increased gradually or in other words, the car with highest year of service has lowest selling price i.e, the oldest car has lowest selling price

# %%
plt.figure()
DF.groupby('year_of_service')['selling_price'].mean().plot(kind='bar')

# %%
sns.scatterplot(x='km_driven', y='selling_price',data=DF )

# %%
plt.figure()
DF.groupby('fuel')['selling_price'].mean().plot(kind='bar')

# %% [markdown]
# The above graph says that Diesel car has the highest mean selling price

# %%
plt.figure()
DF.groupby('owner')['selling_price'].mean().plot(kind='bar')

# %% [markdown]
# Inference: From the above graph we can say that Test Drive Car has the highest average selling price

# %%
plt.figure()
DF.groupby('transmission')['selling_price'].mean().plot(kind='bar')

# %% [markdown]
# In the above graph we can see that Automatic car has the highest average selling price

# %%
from datetime import date

# %%
new_data.show(5)
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|current_year|year_of_service|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|        2023|              9|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# only showing top 5 rows

# %%
new_data = spark.createDataFrame(DF.rename_axis('name').reset_index() )
#spark.createDataFrame(data_clean.rename_axis('name').reset_index())

# %%
new_data.show()
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|current_year|year_of_service|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|        2023|              9|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual| First Owner|        2023|              7|
# |Tata Indigo Grand...|2014|       240000|    60000|Petrol| Individual|      Manual|Second Owner|        2023|              9|
# |Hyundai Creta 1.6...|2015|       850000|    25000|Petrol| Individual|      Manual| First Owner|        2023|              8|
# |Maruti Celerio Gr...|2017|       365000|    78000|   CNG| Individual|      Manual| First Owner|        2023|              6|
# |Chevrolet Sail 1....|2015|       260000|    35000|Petrol| Individual|      Manual| First Owner|        2023|              8|
# |Tata Indigo Grand...|2014|       250000|   100000|Petrol| Individual|      Manual| First Owner|        2023|              9|
# |Toyota Corolla Al...|2018|      1650000|    25000|Petrol|     Dealer|   Automatic| First Owner|        2023|              5|
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|Second Owner|        2023|              9|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual| First Owner|        2023|              7|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+------------+---------------+
# only showing top 20 rows

# %%
new_data.select('year_of_service').distinct().rdd.map(lambda r: r[0]).collect()
# Out:
# [26,
#  19,
#  22,
#  7,
#  25,
#  6,
#  9,
#  27,
#  17,
#  28,
#  5,
#  10,
#  3,
#  12,
#  8,
#  11,
#  4,
#  13,
#  18,
#  14,
#  21,
#  15,
#  23,
#  20,
#  16,
#  24,
#  31]

# %% [markdown]
# Above we can see that the year_of_service column doesn't have any single instance. If it would have any value 1 then it would have to be deleted.

# %% [markdown]
# ##Checking For Correlation

# %%
from pyspark.sql.functions import corr

# %%
new_data.corr('km_driven','selling_price')
# Out:
# -0.19229829804919749

# %%
new_data.corr('year_of_service','selling_price')
# Out:
# -0.41393195880109773

# %%
type(new_data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# Removing Unnecessary Columns: The 'name' column doesn't seem to be necessary. So removing that. As well as the 'current_year' , 'current_date', 'year'

# %%
new_data = new_data.drop("current_date", "current_year", "name","year")

# %%
new_data.show(5)
# Out:
# +-------------+---------+------+-----------+------------+------------+---------------+
# |selling_price|km_driven|  fuel|seller_type|transmission|       owner|year_of_service|
# +-------------+---------+------+-----------+------------+------------+---------------+
# |        60000|    70000|Petrol| Individual|      Manual| First Owner|             16|
# |       135000|    50000|Petrol| Individual|      Manual| First Owner|             16|
# |       600000|   100000|Diesel| Individual|      Manual| First Owner|             11|
# |       250000|    46000|Petrol| Individual|      Manual| First Owner|              6|
# |       450000|   141000|Diesel| Individual|      Manual|Second Owner|              9|
# +-------------+---------+------+-----------+------------+------------+---------------+
# only showing top 5 rows

# %%
from pyspark.ml.feature import StringIndexer

# %%
from pyspark.ml.feature import OneHotEncoder

# %%
from pyspark.ml.feature import VectorAssembler

# %%
type_indexer = StringIndexer(inputCol="fuel", outputCol="fuel_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="fuel_indexer", outputCol="fuel_Vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
type_indexer = StringIndexer(inputCol="seller_type", outputCol="seller_type_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="seller_type_indexer", outputCol="seller_type_vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
type_indexer = StringIndexer(inputCol="owner", outputCol="owner_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="owner_indexer", outputCol="owner_vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
type_indexer = StringIndexer(inputCol="transmission", outputCol="transmission_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="transmission_indexer", outputCol="transmission_vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
new_data.show(3)
# Out:
# +-------------+---------+------+-----------+------------+-----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |selling_price|km_driven|  fuel|seller_type|transmission|      owner|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|
# +-------------+---------+------+-----------+------------+-----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |        60000|    70000|Petrol| Individual|      Manual|First Owner|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       135000|    50000|Petrol| Individual|      Manual|First Owner|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       600000|   100000|Diesel| Individual|      Manual|First Owner|             11|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# +-------------+---------+------+-----------+------------+-----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# only showing top 3 rows

# %%
new_data1 = new_data.drop("fuel","seller_type","owner","transmission")

# %%
new_data1.show(5)
# Out:
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |selling_price|km_driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |        60000|    70000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       135000|    50000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       600000|   100000|             11|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       250000|    46000|              6|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       450000|   141000|              9|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# only showing top 5 rows

# %%
from pyspark.ml.linalg import DenseVector

# %%
from pyspark.ml.feature import StandardScaler

# %%
input_data = new_data.rdd.map(lambda x: (x[0], DenseVector(x[1:])))

# %%
df_assembler = VectorAssembler(inputCols=['km_driven', 'year_of_service', 'fuel_Vector', 'seller_type_vector', 
                                          'owner_vector', 'transmission_vector'], outputCol="features")
#df = df_assembler.transform(df)

# %%
df = df_assembler.transform(new_data1)

# %%
df.show(5)
# Out:
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+
# |selling_price|km_driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|            features|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+
# |        60000|    70000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|
# |       135000|    50000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|
# |       600000|   100000|             11|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|
# |       250000|    46000|              6|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|
# |       450000|   141000|              9|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+
# only showing top 5 rows

# %%
df.select(['features','selling_price']).show(5)
# Out:
# +--------------------+-------------+
# |            features|selling_price|
# +--------------------+-------------+
# |(12,[0,1,3,5,7,11...|        60000|
# |(12,[0,1,3,5,7,11...|       135000|
# |(12,[0,1,2,5,7,11...|       600000|
# |(12,[0,1,3,5,7,11...|       250000|
# |(12,[0,1,2,5,8,11...|       450000|
# +--------------------+-------------+
# only showing top 5 rows

# %% [markdown]
# #Building and Comparing ML Models

# %%
from pyspark.ml.feature import StandardScaler

# %%
# Initialize the `standardScaler`
standardScaler = StandardScaler(inputCol="features", outputCol="features_scaled")

# %%
# Fit the DataFrame to the scaler
scaler = standardScaler.fit(df)

# %%
# Transform the data in `df` with the scaler
scaled_df = scaler.transform(df)

# %%
scaled_df.take(2)
# Out:
# [Row(selling_price=60000, km_driven=70000, year_of_service=16, fuel_indexer=1.0, fuel_Vector=SparseVector(3, {1: 1.0}), seller_type_indexer=0.0, seller_type_vector=SparseVector(2, {0: 1.0}), owner_indexer=0.0, owner_vector=SparseVector(4, {0: 1.0}), transmission_indexer=0.0, transmission_vector=SparseVector(1, {0: 1.0}), features=SparseVector(12, {0: 70000.0, 1: 16.0, 3: 1.0, 5: 1.0, 7: 1.0, 11: 1.0}), features_scaled=SparseVector(12, {0: 1.5006, 1: 3.7965, 3: 2.0002, 5: 2.3019, 7: 2.1001, 11: 3.2893})),
#  Row(selling_price=135000, km_driven=50000, year_of_service=16, fuel_indexer=1.0, fuel_Vector=SparseVector(3, {1: 1.0}), seller_type_indexer=0.0, seller_type_vector=SparseVector(2, {0: 1.0}), owner_indexer=0.0, owner_vector=SparseVector(4, {0: 1.0}), transmission_indexer=0.0, transmission_vector=SparseVector(1, {0: 1.0}), features=SparseVector(12, {0: 50000.0, 1: 16.0, 3: 1.0, 5: 1.0, 7: 1.0, 11: 1.0}), features_scaled=SparseVector(12, {0: 1.0718, 1: 3.7965, 3: 2.0002, 5: 2.3019, 7: 2.1001, 11: 3.2893}))]

# %%
# Split the data into train and test sets
train_data, test_data = scaled_df.randomSplit([.7,.3],seed=1234)

# %%
train_data.show()
# Out:
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+
# |selling_price|km_driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|            features|     features_scaled|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+
# |        40000|    30000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|
# |        40000|    40000|             25|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,10,1...|(12,[0,1,3,5,10,1...|
# |        45000|     7000|              9|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|
# |        45000|    72539|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|
# |        45000|   120000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        50000|    35000|             25|         3.0|    (3,[],[])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,5,8,11],...|(12,[0,1,5,8,11],...|
# |        50000|    60000|             23|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|
# |        50000|    70000|             15|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|
# |        50000|    88500|             23|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,10,1...|(12,[0,1,3,5,10,1...|
# |        50000|   120000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,10,1...|(12,[0,1,2,5,10,1...|
# |        50000|   120000|             20|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        50000|   120000|             24|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|
# |        52000|    50000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        52000|    50000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        52000|   120000|             17|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        55000|    25000|             10|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,10,1...|(12,[0,1,3,5,10,1...|
# |        55000|    35000|             20|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        55000|    60000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        55000|   100000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        55000|   195000|             16|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,9,11...|(12,[0,1,2,5,9,11...|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Import `LinearRegression`
from pyspark.ml.regression import LinearRegression

# %%
# Initialize `lr`
lr = LinearRegression(labelCol="selling_price", maxIter=10, regParam=0.3, elasticNetParam=0.8)

# %%
# Fit the data to the model
linearModel = lr.fit(train_data)

# %%
# Generate predictions
predicted = linearModel.transform(test_data)
predicted.show()
# Out:
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+-------------------+
# |selling_price|km_driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|            features|     features_scaled|         prediction|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+-------------------+
# |        35000|    35000|             11|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...| 205916.26957690553|
# |        40000|    19000|             12|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| 223158.07804130227|
# |        43000|   100000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|-225839.73116515344|
# |        55000|   100000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|(12,[0,1,2,5,7,11...|   274704.846923081|
# |        57000|    80000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...| 259595.46125896228|
# |        58000|    27974|             10|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| 287609.80549445376|
# |        60000|    35000|             20|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| -74363.23081572191|
# |        60000|    35000|             24|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|-247416.49868184282|
# |        60000|    40000|             12|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|  207087.4294376953|
# |        60000|    50000|             21|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|-121501.89117746428|
# |        60000|    50000|             23|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|-192821.14246722357|
# |        60000|   120000|             17|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...| -73089.34768792614|
# |        68000|   120000|             14|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...| 44131.894371401286|
# |        69000|   100000|             15|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| 54192.413635606645|
# |        70000|    80000|             18|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|(12,[0,1,2,5,7,11...| 254350.60090068425|
# |        70000|    90000|             20|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|-146867.79006415256|
# |        70000|   110000|             17|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...| -65436.65787668456|
# |        70000|   120000|             18|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|(12,[0,1,2,5,7,11...| 223739.84165571793|
# |        75000|    29900|             11|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|  250476.2717919289|
# |        75000|    35000|             11|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|   216158.634701594|
# +-------------+---------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+-------------------+
# only showing top 20 rows

# %%
# Coefficients for the model
linearModel.coefficients
# Out:
# DenseVector([-0.7653, -35659.6256, 159592.4158, -132239.2687, -129875.545, -176054.7338, -119577.9946, 13465.6732, -16949.0921, -27191.4572, 5436.1468, -877696.5257])

# %%
# Intercept for the model
linearModel.intercept
# Out:
# 1838138.5514906717

# %%
# Get the RMSE
linearModel.summary.rootMeanSquaredError
# Out:
# 401906.50516186724

# %%
# Get the R2
linearModel.summary.r2
# Out:
# 0.4794838844239636
